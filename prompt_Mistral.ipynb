# %%
! pip install mistralai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from mistralai import Mistral

# %%
import pandas as pd

# Ruta del archivo
file_path = '/Datasets/translated_dataset.csv'

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv(file_path)

# Mostrar las primeras filas del DataFrame
df
# Out:
#                                                    text label
# 0     ¡Hola!\nHe estado queriendo escribir durante a...    B2
# 1     No fue tanto lo difícil que la gente encontró ...    B2
# 2     Keith recientemente regresó de un viaje a Chic...    B2
# 3     El Observatorio Griffith es un planetario y un...    B2
# 4     -LRB- The Hollywood Reporter -RRB- Es oficial:...    B2
# ...                                                 ...   ...
# 1489  La propagación de la luz en las proximidades d...    C2
# 1490  El futuro de la odontología se ha convertido e...    C2
# 1491  Los bosques –y los suburbios– de Europa están ...    C2
# 1492  Los fondos de cobertura se están volviendo alc...    C2
# 1493  Sin calentamiento adicional, el enfriamiento r...    C2
#
# [1494 rows x 2 columns]

# %%
api_key = "API_KEY"

# %%
def run_mistral(user_message, model="mistral-large-latest"):
    client = Mistral(api_key=api_key)
    messages = [
        {"role":"user", "content":user_message}
    ]
    chat_response = client.chat.complete(
        model=model,
        messages=messages
    )
    return (chat_response.choices[0].message.content)

# %%
print(df.iloc[0, 1])
print(df.iloc[0, 0])
# Out:
# B2
# ¡Hola!
# He estado queriendo escribir durante años y finalmente hoy estoy haciendo algo al respecto. No es que esté tratando de excusarme, ha sido muy difícil sentarme y escribir, ya que me he estado moviendo tanto. Desde la última vez que nos vimos, he desempacado mis maletas en cuatro ciudades diferentes. Este trabajo ha resultado ser más de un torbellino de lo que esperaba, ¡pero todo está bien!
# Fui de Londres a Praga para establecer una nueva oficina regional allí. Sabes que siempre quise ir, pero tal vez estaba imaginando Praga en primavera cuando solía hablar de eso. El invierno era muy duro, con menos 15 grados en las mañanas y oscuro muy temprano en la noche. Pero al menos eran cielos azules y nieve blanca y no días al final de cielos grises y lluvia, como en casa. Es difícil estar lejos de casa en Navidad, sin embargo, y Skype el día de Navidad no era lo mismo que estar con todos.
# ...

# %%
prompt = lambda label, text:  f"""

A continuación, te proporcionaré un texto en español y te pediré que lo modifiques para diferentes niveles de competencia lingüística
(A1, A2, B1, B2, C1 y C2), concretamente: {label}. El objetivo es que adaptes el texto según el nivel de dificultad, modificando el
vocabulario y las estructuras gramaticales para que se ajusten a cada nivel, pero manteniendo el mismo mensaje central. Solo responde
con la version del texto modificada para dicho nivel. No incluyas ninguna introducción, título, explicación o comentario adicional. Solo
el texto adaptado.

#Texto original
{text}
"""

# %%
print(run_mistral(prompt('A1', df.iloc[0, 0])))
# Out:
# #Texto adaptado para nivel A1
#
# ¡Hola!
# Quería escribir hace mucho tiempo y hoy lo hago. No es fácil sentarme a escribir porque voy a muchos sitios. Desde la última vez que nos vimos, he vivido en cuatro ciudades. El trabajo es más difícil de lo que pensaba, ¡pero todo está bien!
#
# Fui de Londres a Praga para abrir una oficina nueva. Siempre quise ir a Praga, pero el invierno era muy frío, con menos 15 grados y noches oscuras. Pero había cielos azules y nieve. Es difícil estar lejos de casa en Navidad, y hablar por Skype no es lo mismo que estar con todos.
#
# Luego fui a Nueva York por tres meses para otra oficina. ¡Me encanta Nueva York! Es como estar en una película. Hice cosas de turista y comí mucho. Fue difícil ir al siguiente trabajo, especialmente porque conocí a alguien. Te cuento más sobre Michael después.
#
# ...
